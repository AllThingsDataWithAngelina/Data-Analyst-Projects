# %% [markdown]
# # EDA

# %% [markdown]
# ### Importing libraries

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

pd.set_option('display.max_column', 55)

# %%
#Getting Data
df = pd.read_csv('public_up_to_150k_12_220102.csv')

# %%
df.head()
# Out:
#    LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 0  6214548307   01/26/2021            304              PPS
# 1  3199818509   02/23/2021            304              PPS
# 2  5012337108   04/13/2020            304              PPP
# 3  5288047410   05/12/2020            304              PPP
# 4  1687107207   04/15/2020            304              PPP
#
#                                   BorrowerName           BorrowerAddress  \
# 0              BEDFORD FAMILY URGENT CARE INC.         1368 American Way
# 1                WHITE ELECTRICAL SERVICES LLC             2431 Bluff Rd
# 2  SOUTH BOSTON HARDWARE & POWER EQUIPMENT INC          307 Broad Street
# 3                     COMPLETE CONTRACTING LLC                 PO Box 39
# 4                   NORTON TRACT & ROLLER, INC  1509 MAIN AVE PO Box 566
#
#    BorrowerCity BorrowerState BorrowerZip LoanStatusDate    LoanStatus  Term  \
# 0       Bedford            VA  24523-2940     09/17/2021  Paid in Full    60
# 1       Roanoke            VA  24014-3903            NaN   Exemption 4    60
# 2  SOUTH BOSTON            VA  24592-4611     02/20/2021  Paid in Full    24
# 3    Sutherland            VA       23885     06/17/2021  Paid in Full    24
# 4        NORTON            VA  24273-2209     01/07/2021  Paid in Full    24
#
#    SBAGuarantyPercentage  InitialApprovalAmount  CurrentApprovalAmount  \
# 0                    100               88459.95               88459.95
# 1                    100               88453.30               88453.30
# 2                    100               88445.58               88445.58
# 3                    100               88445.00               88445.00
# 4                    100               88437.90               88437.90
#
#    UndisbursedAmount FranchiseName  ServicingLenderLocationID  \
# 0                0.0           NaN                     447640
# 1                0.0           NaN                      73215
# 2                0.0           NaN                      73481
# 3                0.0           NaN                     225134
# 4                0.0           NaN                     123348
#
#                            ServicingLenderName ServicingLenderAddress  \
# 0                                  Select Bank       211 Gristmill Dr
# 1     American National Bank and Trust Company            628 Main St
# 2                     Benchmark Community Bank         204 S Broad St
# 3  Truist Bank d/b/a Branch Banking & Trust Co         214 N Tryon St
# 4                       New Peoples Bank, Inc.         53 Commerce Dr
#
#   ServicingLenderCity ServicingLenderState ServicingLenderZip  \
# 0              FOREST                   VA         24551-2605
# 1            DANVILLE                   VA         24541-1320
# 2           KENBRIDGE                   VA              23944
# 3           CHARLOTTE                   NC         28202-1078
# 4             HONAKER                   VA              24260
#
#   RuralUrbanIndicator HubzoneIndicator LMIIndicator  \
# 0                   R                Y            N
# 1                   U                N            N
# 2                   R                Y            N
# 3                   R                N            N
# 4                   U                N            Y
#
#               BusinessAgeDescription   ProjectCity ProjectCountyName  \
# 0  Existing or more than 2 years old       Bedford           BEDFORD
# 1  Existing or more than 2 years old       Roanoke           ROANOKE
# 2  Existing or more than 2 years old  SOUTH BOSTON           HALIFAX
# 3  Existing or more than 2 years old    Sutherland         DINWIDDIE
# 4  Existing or more than 2 years old        NORTON       NORTON CITY
#
#   ProjectState  ProjectZip     CD  JobsReported  NAICSCode        Race  \
# 0           VA  24523-2940  VA-05           7.0   621111.0  Unanswered
# 1           VA  24014-3903  VA-06          10.0   238210.0  Unanswered
# 2           VA  24592-4611  VA-05          13.0   444130.0  Unanswered
# 3           VA  23885-0001  VA-04          11.0   531110.0  Unanswered
# 4           VA  24273-2209  VA-09          16.0   811310.0  Unanswered
#
#            Ethnicity  UTILITIES_PROCEED  PAYROLL_PROCEED  \
# 0  Unknown/NotStated                NaN         88459.95
# 1  Unknown/NotStated                NaN         88453.30
# 2  Unknown/NotStated           11055.69         66334.20
# 3  Unknown/NotStated                NaN         88445.00
# 4  Unknown/NotStated                NaN         88437.90
#
#    MORTGAGE_INTEREST_PROCEED  RENT_PROCEED  REFINANCE_EIDL_PROCEED  \
# 0                        NaN           NaN                     NaN
# 1                        NaN           NaN                     NaN
# 2                   11055.69           NaN                     NaN
# 3                        NaN           NaN                     NaN
# 4                        NaN           NaN                     NaN
#
#    HEALTH_CARE_PROCEED  DEBT_INTEREST_PROCEED  \
# 0                  NaN                    NaN
# 1                  NaN                    NaN
# 2                  NaN                    NaN
# 3                  NaN                    NaN
# 4                  NaN                    NaN
#
#                       BusinessType  OriginatingLenderLocationID  \
# 0         Subchapter S Corporation                       447640
# 1  Limited  Liability Company(LLC)                        73215
# 2                      Corporation                        73481
# 3  Limited  Liability Company(LLC)                       225134
# 4                      Corporation                       123348
#
#                              OriginatingLender OriginatingLenderCity  \
# 0                                  Select Bank                FOREST
# 1     American National Bank and Trust Company              DANVILLE
# 2                     Benchmark Community Bank             KENBRIDGE
# 3  Truist Bank d/b/a Branch Banking & Trust Co             CHARLOTTE
# 4                       New Peoples Bank, Inc.               HONAKER
#
#   OriginatingLenderState      Gender     Veteran NonProfit  ForgivenessAmount  \
# 0                     VA  Unanswered  Unanswered       NaN           88898.61
# 1                     VA  Unanswered  Unanswered       NaN           89151.10
# 2                     VA  Unanswered  Unanswered       NaN           89094.99
# 3                     NC  Unanswered  Unanswered       NaN           89356.47
# 4                     VA  Unanswered  Unanswered       NaN           89037.31
#
#   ForgivenessDate
# 0      08/06/2021
# 1      12/07/2021
# 2      01/14/2021
# 3      05/25/2021
# 4      12/28/2020

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 601263 entries, 0 to 601262
# Data columns (total 53 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   LoanNumber                   601263 non-null  int64
#  1   DateApproved                 601263 non-null  object
#  2   SBAOfficeCode                601263 non-null  int64
#  3   ProcessingMethod             601263 non-null  object
#  4   BorrowerName                 601254 non-null  object
#  5   BorrowerAddress              601257 non-null  object
#  6   BorrowerCity                 601258 non-null  object
#  7   BorrowerState                601263 non-null  object
#  8   BorrowerZip                  601258 non-null  object
#  9   LoanStatusDate               443936 non-null  object
#  10  LoanStatus                   601263 non-null  object
#  11  Term                         601263 non-null  int64
#  12  SBAGuarantyPercentage        601263 non-null  int64
#  13  InitialApprovalAmount        601263 non-null  float64
#  14  CurrentApprovalAmount        601263 non-null  float64
#  15  UndisbursedAmount            600942 non-null  float64
#  16  FranchiseName                8281 non-null    object
#  17  ServicingLenderLocationID    601263 non-null  int64
#  18  ServicingLenderName          601263 non-null  object
#  19  ServicingLenderAddress       601263 non-null  object
#  20  ServicingLenderCity          601263 non-null  object
#  21  ServicingLenderState         601263 non-null  object
#  22  ServicingLenderZip           601263 non-null  object
#  23  RuralUrbanIndicator          601263 non-null  object
#  24  HubzoneIndicator             601263 non-null  object
#  25  LMIIndicator                 601263 non-null  object
#  26  BusinessAgeDescription       601263 non-null  object
#  27  ProjectCity                  601258 non-null  object
#  28  ProjectCountyName            601237 non-null  object
#  29  ProjectState                 601263 non-null  object
#  30  ProjectZip                   601258 non-null  object
#  31  CD                           601244 non-null  object
#  32  JobsReported                 601262 non-null  float64
#  33  NAICSCode                    595952 non-null  float64
#  34  Race                         601263 non-null  object
#  35  Ethnicity                    601263 non-null  object
#  36  UTILITIES_PROCEED            172404 non-null  float64
#  37  PAYROLL_PROCEED              600629 non-null  float64
#  38  MORTGAGE_INTEREST_PROCEED    14813 non-null   float64
#  39  RENT_PROCEED                 21667 non-null   float64
#  40  REFINANCE_EIDL_PROCEED       3592 non-null    float64
#  41  HEALTH_CARE_PROCEED          5927 non-null    float64
#  42  DEBT_INTEREST_PROCEED        3779 non-null    float64
#  43  BusinessType                 601200 non-null  object
#  44  OriginatingLenderLocationID  601263 non-null  int64
#  45  OriginatingLender            601263 non-null  object
#  46  OriginatingLenderCity        601263 non-null  object
#  47  OriginatingLenderState       601263 non-null  object
#  48  Gender                       601263 non-null  object
#  49  Veteran                      601263 non-null  object
#  50  NonProfit                    17919 non-null   object
#  51  ForgivenessAmount            503999 non-null  float64
#  52  ForgivenessDate              503999 non-null  object
# dtypes: float64(13), int64(6), object(34)
# memory usage: 243.1+ MB

# %%
#checking for nulls
df.isnull().sum()
# Out:
# LoanNumber                          0
# DateApproved                        0
# SBAOfficeCode                       0
# ProcessingMethod                    0
# BorrowerName                        9
# BorrowerAddress                     6
# BorrowerCity                        5
# BorrowerState                       0
# BorrowerZip                         5
# LoanStatusDate                 157327
# LoanStatus                          0
# Term                                0
# SBAGuarantyPercentage               0
# InitialApprovalAmount               0
# CurrentApprovalAmount               0
# UndisbursedAmount                 321
# FranchiseName                  592982
# ServicingLenderLocationID           0
# ServicingLenderName                 0
# ServicingLenderAddress              0
# ServicingLenderCity                 0
# ServicingLenderState                0
# ServicingLenderZip                  0
# RuralUrbanIndicator                 0
# HubzoneIndicator                    0
# LMIIndicator                        0
# BusinessAgeDescription              0
# ProjectCity                         5
# ProjectCountyName                  26
# ProjectState                        0
# ProjectZip                          5
# CD                                 19
# JobsReported                        1
# NAICSCode                        5311
# Race                                0
# Ethnicity                           0
# UTILITIES_PROCEED              428859
# PAYROLL_PROCEED                   634
# MORTGAGE_INTEREST_PROCEED      586450
# RENT_PROCEED                   579596
# REFINANCE_EIDL_PROCEED         597671
# HEALTH_CARE_PROCEED            595336
# DEBT_INTEREST_PROCEED          597484
# BusinessType                       63
# OriginatingLenderLocationID         0
# OriginatingLender                   0
# OriginatingLenderCity               0
# OriginatingLenderState              0
# Gender                              0
# Veteran                             0
# NonProfit                      583344
# ForgivenessAmount               97264
# ForgivenessDate                 97264
# dtype: int64

# %%
df = df.loc[df['BorrowerName'].notnull()]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 601254 entries, 0 to 601262
# Data columns (total 53 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   LoanNumber                   601254 non-null  int64
#  1   DateApproved                 601254 non-null  object
#  2   SBAOfficeCode                601254 non-null  int64
#  3   ProcessingMethod             601254 non-null  object
#  4   BorrowerName                 601254 non-null  object
#  5   BorrowerAddress              601248 non-null  object
#  6   BorrowerCity                 601249 non-null  object
#  7   BorrowerState                601254 non-null  object
#  8   BorrowerZip                  601249 non-null  object
#  9   LoanStatusDate               443929 non-null  object
#  10  LoanStatus                   601254 non-null  object
#  11  Term                         601254 non-null  int64
#  12  SBAGuarantyPercentage        601254 non-null  int64
#  13  InitialApprovalAmount        601254 non-null  float64
#  14  CurrentApprovalAmount        601254 non-null  float64
#  15  UndisbursedAmount            600933 non-null  float64
#  16  FranchiseName                8281 non-null    object
#  17  ServicingLenderLocationID    601254 non-null  int64
#  18  ServicingLenderName          601254 non-null  object
#  19  ServicingLenderAddress       601254 non-null  object
#  20  ServicingLenderCity          601254 non-null  object
#  21  ServicingLenderState         601254 non-null  object
#  22  ServicingLenderZip           601254 non-null  object
#  23  RuralUrbanIndicator          601254 non-null  object
#  24  HubzoneIndicator             601254 non-null  object
#  25  LMIIndicator                 601254 non-null  object
#  26  BusinessAgeDescription       601254 non-null  object
#  27  ProjectCity                  601249 non-null  object
#  28  ProjectCountyName            601228 non-null  object
#  29  ProjectState                 601254 non-null  object
#  30  ProjectZip                   601249 non-null  object
#  31  CD                           601235 non-null  object
#  32  JobsReported                 601253 non-null  float64
#  33  NAICSCode                    595944 non-null  float64
#  34  Race                         601254 non-null  object
#  35  Ethnicity                    601254 non-null  object
#  36  UTILITIES_PROCEED            172403 non-null  float64
#  37  PAYROLL_PROCEED              600620 non-null  float64
#  38  MORTGAGE_INTEREST_PROCEED    14813 non-null   float64
#  39  RENT_PROCEED                 21667 non-null   float64
#  40  REFINANCE_EIDL_PROCEED       3592 non-null    float64
#  41  HEALTH_CARE_PROCEED          5927 non-null    float64
#  42  DEBT_INTEREST_PROCEED        3779 non-null    float64
#  43  BusinessType                 601191 non-null  object
#  44  OriginatingLenderLocationID  601254 non-null  int64
#  45  OriginatingLender            601254 non-null  object
#  46  OriginatingLenderCity        601254 non-null  object
#  47  OriginatingLenderState       601254 non-null  object
#  48  Gender                       601254 non-null  object
#  49  Veteran                      601254 non-null  object
#  50  NonProfit                    17919 non-null   object
#  51  ForgivenessAmount            503992 non-null  float64
#  52  ForgivenessDate              503992 non-null  object
# dtypes: float64(13), int64(6), object(34)
# memory usage: 247.7+ MB

# %%
#add a few more columns to our df for analysis
df['year_approved'] = pd.DatetimeIndex(df['DateApproved']).year
df['month_approved'] = pd.DatetimeIndex(df['DateApproved']).month

df['year_forgiven'] = pd.DatetimeIndex(df['ForgivenessDate']).year
df['month_forgiven'] = pd.DatetimeIndex(df['ForgivenessDate']).month

# %%
df.head()
# Out:
#    LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 0  6214548307   01/26/2021            304              PPS
# 1  3199818509   02/23/2021            304              PPS
# 2  5012337108   04/13/2020            304              PPP
# 3  5288047410   05/12/2020            304              PPP
# 4  1687107207   04/15/2020            304              PPP
#
#                                   BorrowerName           BorrowerAddress  \
# 0              BEDFORD FAMILY URGENT CARE INC.         1368 American Way
# 1                WHITE ELECTRICAL SERVICES LLC             2431 Bluff Rd
# 2  SOUTH BOSTON HARDWARE & POWER EQUIPMENT INC          307 Broad Street
# 3                     COMPLETE CONTRACTING LLC                 PO Box 39
# 4                   NORTON TRACT & ROLLER, INC  1509 MAIN AVE PO Box 566
#
#    BorrowerCity BorrowerState BorrowerZip LoanStatusDate    LoanStatus  Term  \
# 0       Bedford            VA  24523-2940     09/17/2021  Paid in Full    60
# 1       Roanoke            VA  24014-3903            NaN   Exemption 4    60
# 2  SOUTH BOSTON            VA  24592-4611     02/20/2021  Paid in Full    24
# 3    Sutherland            VA       23885     06/17/2021  Paid in Full    24
# 4        NORTON            VA  24273-2209     01/07/2021  Paid in Full    24
#
#    SBAGuarantyPercentage  InitialApprovalAmount  CurrentApprovalAmount  \
# 0                    100               88459.95               88459.95
# 1                    100               88453.30               88453.30
# 2                    100               88445.58               88445.58
# 3                    100               88445.00               88445.00
# 4                    100               88437.90               88437.90
#
#    UndisbursedAmount FranchiseName  ServicingLenderLocationID  \
# 0                0.0           NaN                     447640
# 1                0.0           NaN                      73215
# 2                0.0           NaN                      73481
# 3                0.0           NaN                     225134
# 4                0.0           NaN                     123348
#
#                            ServicingLenderName ServicingLenderAddress  \
# 0                                  Select Bank       211 Gristmill Dr
# 1     American National Bank and Trust Company            628 Main St
# 2                     Benchmark Community Bank         204 S Broad St
# 3  Truist Bank d/b/a Branch Banking & Trust Co         214 N Tryon St
# 4                       New Peoples Bank, Inc.         53 Commerce Dr
#
#   ServicingLenderCity ServicingLenderState ServicingLenderZip  \
# 0              FOREST                   VA         24551-2605
# 1            DANVILLE                   VA         24541-1320
# 2           KENBRIDGE                   VA              23944
# 3           CHARLOTTE                   NC         28202-1078
# 4             HONAKER                   VA              24260
#
#   RuralUrbanIndicator HubzoneIndicator LMIIndicator  \
# 0                   R                Y            N
# 1                   U                N            N
# 2                   R                Y            N
# 3                   R                N            N
# 4                   U                N            Y
#
#               BusinessAgeDescription  ...  ProjectZip     CD JobsReported  \
# 0  Existing or more than 2 years old  ...  24523-2940  VA-05          7.0
# 1  Existing or more than 2 years old  ...  24014-3903  VA-06         10.0
# 2  Existing or more than 2 years old  ...  24592-4611  VA-05         13.0
# 3  Existing or more than 2 years old  ...  23885-0001  VA-04         11.0
# 4  Existing or more than 2 years old  ...  24273-2209  VA-09         16.0
#
#   NAICSCode        Race          Ethnicity  UTILITIES_PROCEED PAYROLL_PROCEED  \
# 0  621111.0  Unanswered  Unknown/NotStated                NaN        88459.95
# 1  238210.0  Unanswered  Unknown/NotStated                NaN        88453.30
# 2  444130.0  Unanswered  Unknown/NotStated           11055.69        66334.20
# 3  531110.0  Unanswered  Unknown/NotStated                NaN        88445.00
# 4  811310.0  Unanswered  Unknown/NotStated                NaN        88437.90
#
#   MORTGAGE_INTEREST_PROCEED  RENT_PROCEED  REFINANCE_EIDL_PROCEED  \
# 0                       NaN           NaN                     NaN
# 1                       NaN           NaN                     NaN
# 2                  11055.69           NaN                     NaN
# 3                       NaN           NaN                     NaN
# 4                       NaN           NaN                     NaN
#
#    HEALTH_CARE_PROCEED  DEBT_INTEREST_PROCEED  \
# 0                  NaN                    NaN
# 1                  NaN                    NaN
# 2                  NaN                    NaN
# 3                  NaN                    NaN
# 4                  NaN                    NaN
#
#                       BusinessType  OriginatingLenderLocationID  \
# 0         Subchapter S Corporation                       447640
# 1  Limited  Liability Company(LLC)                        73215
# 2                      Corporation                        73481
# 3  Limited  Liability Company(LLC)                       225134
# 4                      Corporation                       123348
#
#                              OriginatingLender OriginatingLenderCity  \
# 0                                  Select Bank                FOREST
# 1     American National Bank and Trust Company              DANVILLE
# 2                     Benchmark Community Bank             KENBRIDGE
# 3  Truist Bank d/b/a Branch Banking & Trust Co             CHARLOTTE
# 4                       New Peoples Bank, Inc.               HONAKER
#
#    OriginatingLenderState      Gender     Veteran NonProfit ForgivenessAmount  \
# 0                      VA  Unanswered  Unanswered       NaN          88898.61
# 1                      VA  Unanswered  Unanswered       NaN          89151.10
# 2                      VA  Unanswered  Unanswered       NaN          89094.99
# 3                      NC  Unanswered  Unanswered       NaN          89356.47
# 4                      VA  Unanswered  Unanswered       NaN          89037.31
#
#   ForgivenessDate year_approved  month_approved year_forgiven  month_forgiven
# 0      08/06/2021          2021               1        2021.0             8.0
# 1      12/07/2021          2021               2        2021.0            12.0
# 2      01/14/2021          2020               4        2021.0             1.0
# 3      05/25/2021          2020               5        2021.0             5.0
# 4      12/28/2020          2020               4        2020.0            12.0
#
# [5 rows x 57 columns]

# %%
FirstRound = df.loc[ df['ProcessingMethod'] == 'PPP']

# %%
SecondRound = df.loc[ df['ProcessingMethod'] == 'PPS']

# %%
FirstRound.head()
# Out:
#    LoanNumber DateApproved  SBAOfficeCode ProcessingMethod  \
# 2  5012337108   04/13/2020            304              PPP
# 3  5288047410   05/12/2020            304              PPP
# 4  1687107207   04/15/2020            304              PPP
# 5  6132267404   05/14/2020            304              PPP
# 8  1715677201   04/15/2020            353              PPP
#
#                                   BorrowerName           BorrowerAddress  \
# 2  SOUTH BOSTON HARDWARE & POWER EQUIPMENT INC          307 Broad Street
# 3                     COMPLETE CONTRACTING LLC                 PO Box 39
# 4                   NORTON TRACT & ROLLER, INC  1509 MAIN AVE PO Box 566
# 5                       COLDEN'S CONCEPTS, LLC            1505 Hibie St.
# 8    WASHINGTON STREET UNITED METHODIST CHURCH      109 S. WASHINGTON ST
#
#    BorrowerCity BorrowerState BorrowerZip LoanStatusDate    LoanStatus  Term  \
# 2  SOUTH BOSTON            VA  24592-4611     02/20/2021  Paid in Full    24
# 3    Sutherland            VA       23885     06/17/2021  Paid in Full    24
# 4        NORTON            VA  24273-2209     01/07/2021  Paid in Full    24
# 5       NORFOLK            VA  23523-1821     04/21/2021  Paid in Full    24
# 8    ALEXANDRIA            VA  22314-3100     04/13/2021  Paid in Full    24
#
#    SBAGuarantyPercentage  InitialApprovalAmount  CurrentApprovalAmount  \
# 2                    100               88445.58               88445.58
# 3                    100               88445.00               88445.00
# 4                    100               88437.90               88437.90
# 5                    100               88433.34               88433.34
# 8                    100               88422.00               88422.00
#
#    UndisbursedAmount FranchiseName  ServicingLenderLocationID  \
# 2                0.0           NaN                      73481
# 3                0.0           NaN                     225134
# 4                0.0           NaN                     123348
# 5                0.0           NaN                     225134
# 8                0.0           NaN                      73056
#
#                            ServicingLenderName ServicingLenderAddress  \
# 2                     Benchmark Community Bank         204 S Broad St
# 3  Truist Bank d/b/a Branch Banking & Trust Co         214 N Tryon St
# 4                       New Peoples Bank, Inc.         53 Commerce Dr
# 5  Truist Bank d/b/a Branch Banking & Trust Co         214 N Tryon St
# 8         Burke & Herbert Bank & Trust Company       100 S Fairfax St
#
#   ServicingLenderCity ServicingLenderState ServicingLenderZip  \
# 2           KENBRIDGE                   VA              23944
# 3           CHARLOTTE                   NC         28202-1078
# 4             HONAKER                   VA              24260
# 5           CHARLOTTE                   NC         28202-1078
# 8          ALEXANDRIA                   VA         22314-3340
#
#   RuralUrbanIndicator HubzoneIndicator LMIIndicator  \
# 2                   R                Y            N
# 3                   R                N            N
# 4                   U                N            Y
# 5                   U                Y            Y
# 8                   U                N            N
#
#               BusinessAgeDescription  ...  ProjectZip     CD JobsReported  \
# 2  Existing or more than 2 years old  ...  24592-4611  VA-05         13.0
# 3  Existing or more than 2 years old  ...  23885-0001  VA-04         11.0
# 4  Existing or more than 2 years old  ...  24273-2209  VA-09         16.0
# 5  Existing or more than 2 years old  ...  23523-1821  VA-03         13.0
# 8  Existing or more than 2 years old  ...  22314-3100  VA-08         20.0
#
#   NAICSCode        Race          Ethnicity  UTILITIES_PROCEED PAYROLL_PROCEED  \
# 2  444130.0  Unanswered  Unknown/NotStated           11055.69        66334.20
# 3  531110.0  Unanswered  Unknown/NotStated                NaN        88445.00
# 4  811310.0  Unanswered  Unknown/NotStated                NaN        88437.90
# 5  238320.0  Unanswered  Unknown/NotStated                NaN        88433.34
# 8  813110.0  Unanswered  Unknown/NotStated                NaN        88422.00
#
#   MORTGAGE_INTEREST_PROCEED  RENT_PROCEED  REFINANCE_EIDL_PROCEED  \
# 2                  11055.69           NaN                     NaN
# 3                       NaN           NaN                     NaN
# 4                       NaN           NaN                     NaN
# 5                       NaN           NaN                     NaN
# 8                       NaN           NaN                     NaN
#
#    HEALTH_CARE_PROCEED  DEBT_INTEREST_PROCEED  \
# 2                  NaN                    NaN
# 3                  NaN                    NaN
# 4                  NaN                    NaN
# 5                  NaN                    NaN
# 8                  NaN                    NaN
#
#                       BusinessType  OriginatingLenderLocationID  \
# 2                      Corporation                        73481
# 3  Limited  Liability Company(LLC)                       225134
# 4                      Corporation                       123348
# 5  Limited  Liability Company(LLC)                       225134
# 8          Non-Profit Organization                        73056
#
#                              OriginatingLender OriginatingLenderCity  \
# 2                     Benchmark Community Bank             KENBRIDGE
# 3  Truist Bank d/b/a Branch Banking & Trust Co             CHARLOTTE
# 4                       New Peoples Bank, Inc.               HONAKER
# 5  Truist Bank d/b/a Branch Banking & Trust Co             CHARLOTTE
# 8         Burke & Herbert Bank & Trust Company            ALEXANDRIA
#
#    OriginatingLenderState      Gender     Veteran NonProfit ForgivenessAmount  \
# 2                      VA  Unanswered  Unanswered       NaN          89094.99
# 3                      NC  Unanswered  Unanswered       NaN          89356.47
# 4                      VA  Unanswered  Unanswered       NaN          89037.31
# 5                      NC  Unanswered  Unanswered       NaN          89187.48
# 8                      VA  Unanswered  Unanswered         Y          89200.60
#
#   ForgivenessDate year_approved  month_approved year_forgiven  month_forgiven
# 2      01/14/2021          2020               4        2021.0             1.0
# 3      05/25/2021          2020               5        2021.0             5.0
# 4      12/28/2020          2020               4        2020.0            12.0
# 5      03/23/2021          2020               5        2021.0             3.0
# 8      03/16/2021          2020               4        2021.0             3.0
#
# [5 rows x 57 columns]

# %% [markdown]
# ## Categorical Variables

# %% [markdown]
# ### Univariable

# %%
## count the how many records there are in each processing method
sns.countplot(df['ProcessingMethod'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='ProcessingMethod', ylabel='count'>

# %%
sns.countplot(df['BorrowerState'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='BorrowerState', ylabel='count'>

# %%
sns.countplot(df['LoanStatus'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='LoanStatus', ylabel='count'>

# %%
sns.countplot(df['Ethnicity'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Ethnicity', ylabel='count'>

# %%
##Rotate the ticklabels
plt.figure(figsize=(15,6)) # this creates a figure 8 inch wide, 4 inch high
ax = sns.countplot(x="BusinessType", data=df)
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
#plt.tight_layout()
plt.show()

# %%
##Rotate the ticklabels
ax = sns.countplot(x="Race", data=df)
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
#plt.tight_layout()
plt.show()

# %% [markdown]
# ### BiVariate

# %%
## Plotting Ethnicity Against Loan Status
sns.countplot(x = 'Ethnicity' , hue ='LoanStatus' , data = df)
# Out:
# <AxesSubplot:xlabel='Ethnicity', ylabel='count'>

# %%
#cross tabulation
pd.crosstab(df['BorrowerState'],df['Ethnicity'])
# Out:
# Ethnicity      Hispanic or Latino  Not Hispanic or Latino  Unknown/NotStated
# BorrowerState
# VA                           2761                   39616             140893
# VI                            163                     888               2062
# VT                             74                    4981              14373
# WA                           3654                   39984             127857
# WI                           1760                   47589             121126
# WV                            158                    9501              20298
# WY                            401                    6075              17040

# %%
pd.crosstab(df['year_approved'], df['BorrowerState'])
# Out:
# BorrowerState     VA    VI     VT     WA     WI     WV     WY
# year_approved
# 2020           87614  1864  10784  90871  76659  15687  12161
# 2021           95656  1249   8644  80624  93816  14270  11355

# %%
pd.crosstab(df['Ethnicity'],df['LoanStatus'])
# Out:
# LoanStatus              Active Un-Disbursed  Exemption 4  Paid in Full
# Ethnicity
# Hispanic or Latino                        1         3238          5732
# Not Hispanic or Latino                    8        45146        103480
# Unknown/NotStated                        16       108941        334692

# %% [markdown]
# ### Numerical Variables - Discrete Variable

# %%
## Descriptive Summary
df['CurrentApprovalAmount'].describe()
# Out:
# count    601254.000000
# mean      27381.242810
# std       28420.922684
# min           1.800000
# 25%        8617.000000
# 50%       19442.000000
# 75%       33600.000000
# max      149999.990000
# Name: CurrentApprovalAmount, dtype: float64

# %% [markdown]
# ### Outliers

# %% [markdown]
# #####  The five-number summary

# %%
sns.boxplot(x = df['CurrentApprovalAmount'])
# Out:
# <AxesSubplot:xlabel='CurrentApprovalAmount'>

# %%
##The five-number summary divides the data into sections that each contain approximately 25 percent of the data in that set.
#The five-number summary is the minimum, first quartile, median, third quartile, and maximum

# Min = Minimum value
# Q1 = The first quartile is the median of the data points to the left of the median
# Median = is the value separating the higher half from the lower half of a data sample, a population or distribution
# Q3 = The third quartile is the median of the data points to the right of the median
# Max = Max value

#About 75 percent of the CurrentApprovalAmount is greater than 8700 dollars per the boxplot above.

# %%
plt.figure(figsize=(15,6)) # this creates a figure 8 inch wide, 4 inch high
sns.boxplot(x="LoanStatus", y="CurrentApprovalAmount", data=df)
# Out:
# <AxesSubplot:xlabel='LoanStatus', ylabel='CurrentApprovalAmount'>

# %%
sns.distplot(df['CurrentApprovalAmount']/10**3)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='CurrentApprovalAmount', ylabel='Density'>

# %%
#Deviates from the normal distribution.
#Have a positive skewness.

# %%
#skewness and kurtosis
#Basically getting the body measure of the above diagram

# %%
#df['CurrentApprovalAmount'].skew()
#df['CurrentApprovalAmount'].kurt()

###Modified as compared to what I showed in Demo
print("Skewness: %f" % df['CurrentApprovalAmount'].skew())
print("Kurtosis: %f" % df['CurrentApprovalAmount'].kurt())
# Out:
# Skewness: 1.938848
# Kurtosis: 3.699537

# %%
#scatter plot ForgivenessAmount/CurrentApprovalAmount
var = 'ForgivenessAmount'
data = pd.concat([df['CurrentApprovalAmount'], df[var]], axis=1)
data.plot.scatter(x='CurrentApprovalAmount', y=var);

# %% [markdown]
# ### Correlation

# %%
##correlation matrix
matrix = df.corr()
f, ax = plt.subplots(figsize=(15, 11))
sns.heatmap(matrix, annot=True)
# Out:
# <AxesSubplot:>
